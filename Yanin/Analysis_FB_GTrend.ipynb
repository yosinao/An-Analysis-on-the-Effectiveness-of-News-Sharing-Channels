# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fb_data = {'Query': ['Justice Department','ISIS',
                     'Frauds and Swindling', 'Sex Crimes',
                     'Immigration',
                     'Espionage and intelligence service',
                     'Presidential election of 2016',
                     'Roman Catholic Church',
                     'Education department (us)', 
                     'Suits and Litigation (Civil)','Democratic Party'], 
           'num_days': [365, 14, 351, 365, 14,337,91,274,351,225,288]}
fb_df = pd.DataFrame(fb_data)
fb_df
# Out:
#                                  Query  num_days
# 0                   Justice Department       365
# 1                                 ISIS        14
# 2                 Frauds and Swindling       351
# 3                           Sex Crimes       365
# 4                          Immigration        14
# 5   Espionage and intelligence service       337
# 6        Presidential election of 2016        91
# 7                Roman Catholic Church       274
# 8            Education department (us)       351
# 9         Suits and Litigation (Civil)       225
# 10                    Democratic Party       288

# %%
plt.bar(fb_df['Query'],fb_df['num_days'],color='b', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.show()
plt.title("Top Queries from Facebook on Google trend")
plt.xlabel("Query")
plt.ylabel("Number of Days over 50%")
plt.savefig("FB_Query.png", bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fb_df.describe()
# Out:
#          num_days
# count   11.000000
# mean   243.181818
# std    139.006344
# min     14.000000
# 25%    158.000000
# 50%    288.000000
# 75%    351.000000
# max    365.000000
