# %%
from pytrends.request import TrendReq
from pprint import pprint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gmaps
import json
import requests
gkey = "AIzaSyDdb6E3Cn4wbQbYrCBPDkge9XQk4k5siMk"

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ['epidemic intelligence service']
pytrends.build_payload(kw_list, cat=0, timeframe='2017-09-07 2018-09-07', geo='US',gprop='')

# %%
overtime_interest = pytrends.interest_over_time()

# %%
overtime_interest.head()
# Out:
#             epidemic intelligence service isPartial
# date
# 2017-09-10                             34     False
# 2017-09-17                             34     False
# 2017-09-24                             35     False
# 2017-10-01                             34     False
# 2017-10-08                             68     False

# %%
lines = overtime_interest.plot.line()
plt.axhline(y=50, color='r', linestyle='-')
plt.show()
