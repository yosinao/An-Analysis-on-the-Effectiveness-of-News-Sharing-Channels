# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
em_data = {'Query': ['Roman Catholic Church', 'United States Government',
                     'Lawsuit','Republican Party', 'Intelligence Service', 
                     'Election of House of Representatives',
                     'New York Times', 'US International Relation',
                     'Democratic Party', 'ISIS'], 
           'num_days': [273,253,365,154,337,28,266,238,288,14]}
em_df = pd.DataFrame(em_data)
em_df
# Out:
#                                   Query  num_days
# 0                 Roman Catholic Church       273
# 1              United States Government       253
# 2                               Lawsuit       365
# 3                      Republican Party       154
# 4                  Intelligence Service       337
# 5  Election of House of Representatives        28
# 6                        New York Times       266
# 7             US International Relation       238
# 8                      Democratic Party       288
# 9                                  ISIS        14

# %%
plt.bar(em_df['Query'],em_df['num_days'],color='g', alpha=0.5, align="center")
plt.xticks(rotation=90)
plt.show()
plt.title("Top Queries from Email on Google trend")
plt.xlabel("Query")
plt.ylabel("Number of Days over 50%")
plt.savefig("EM_Query.png", bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
em_df.describe()
# Out:
#          num_days
# count   10.000000
# mean   221.600000
# std    119.863997
# min     14.000000
# 25%    175.000000
# 50%    259.500000
# 75%    284.250000
# max    365.000000
