# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tw_data = {'Query': ['Intelligence Service', 'United States Government',
                     'Republican party', 'Immigration', 'Democratic Party', 
                     'Sex crimes', 'CIA', 'Missing persons',
                     'Books and Literatures', 'Justice Department', 'Roman Catholic Church',
                     'ISIS', 'Wikileaks'], 
           'num_days': [337,253,154,14,288,365,49,21,281,365,274,14,7]}
tw_df = pd.DataFrame(tw_data)
tw_df
# Out:
#                        Query  num_days
# 0       Intelligence Service       337
# 1   United States Government       253
# 2           Republican party       154
# 3                Immigration        14
# 4           Democratic Party       288
# 5                 Sex crimes       365
# 6                        CIA        49
# 7            Missing persons        21
# 8      Books and Literatures       281
# 9         Justice Department       365
# 10     Roman Catholic Church       274
# 11                      ISIS        14
# 12                 Wikileaks         7

# %%
plt.bar(tw_df['Query'],tw_df['num_days'],color='lightblue', align="center")
plt.xticks(rotation=90)
plt.show()
plt.title("Top Queries from Twitter on Google trend")
plt.xlabel("Query")
plt.ylabel("Number of Days over 50%")
plt.savefig("TW_Query.png", bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tw_df.describe()
# Out:
#          num_days
# count   13.000000
# mean   186.307692
# std    146.279062
# min      7.000000
# 25%     21.000000
# 50%    253.000000
# 75%    288.000000
# max    365.000000
