# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#import gmaps
from pytrends.request import TrendReq
from pprint import pprint
import string

# Import API key
from config import api_key

# %%
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = "trump"

# Search for articles published between a begin and end date
begin_date = "20180801"
end_date = "20180830"

query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = [article for article in articles["response"]["docs"]]


for article in articles_list:
    print(f'A snippet from the article: {article["snippet"]}')
# Out:
# A snippet from the article: The district attorney’s office is weighing whether the company’s false accounting regarding payment to silence an adult film star violates state law.
# A snippet from the article: The more Trump is cornered, the more he mirrors Richard Nixon.
# A snippet from the article: President Trump claimed that the June 2016 meeting was “totally legal,” though it is a key subject of the investigation by the special counsel, Robert S. Mueller III.
# A snippet from the article: Ms. Manigault Newman responded that Mr. Trump, who has also insulted Don Lemon and LeBron James, “has absolutely no respect for women, for African-Americans.’’
# A snippet from the article: A transcript of “that” meeting with the Russians surfaces — and a controversy is settled.
# ...

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Emply list for articles
articles_list = []

# loop through pages 0-2

for page in range(0, 3):
    time.sleep(1)
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
    # create query with page number
    query_url = f"{query_url}&page={str(page)}"
    articles = requests.get(query_url).json()
#     time.sleep(1)
#     pprint(articles)
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
#     loop through the response and append each article to the list
    for article in articles["response"]["docs"]:
        articles_list.append(article)
        
articles_list
# Out:
# [{'web_url': 'https://www.nytimes.com/2018/08/23/nyregion/trump-organization-criminal-charges-vance.html',
#   'snippet': 'The district attorney’s office is weighing whether the company’s false accounting regarding payment to silence an adult film star violates state law.',
#   'print_page': '14',
#   'blog': {},
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2018/08/24/nyregion/24trumporg1/24trumporg1-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2018/08/24/nyregion/24trumporg1/24trumporg1-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
# ...

# %%
#url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
url = f"http://api.nytimes.com/svc/mostpopular/v2/mostviewed/U.S./30.json?offset=40"
#http://api.nytimes.com/svc/mostpopular/v2/mostviewed/arts/30.json?offset=40

# %%
# Search for articles that mention Trump
query = "Trump"

# %%
# Search for most viewed articles published between a begin and end date
begin_date = "20180801"
end_date = "20180830"

#query_url = f"{url}&api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
# query_url = f"{url}&api-key={api_key}"
#query_url

# %%
# Retrieve articles
viewed_articles = requests.get(url).json()
viewed_articles
#articles_list = [article for article in articles["response"][""]]
# Out:
# {'message': 'No API key found in headers or querystring'}

# %% [markdown]
# # Top query List

# %%
type_list = ["Politics",  
             "Blogs", 
             "Books", 
             "Business Day", 
             "Education", 
             "Fashion & Style", 
             "Food", 
             "Health", 
             "Job Market", 
             "Magazine", 
             "membercenter", 
             "Movies", 
             "Multimedia", 
             "N.Y.%20%2F%20Region", 
             "NYT Now", 
             "Obituaries", 
             "Open", 
             "Opinion", 
             "Public Editor", 
             "Real Estate", 
             "Science", 
             "Sports", 
             "Style", 
             "Sunday Review", 
             "T Magazine", 
             "Technology", 
             "The Upshot", 
             "Theater", 
             "Times Insider", 
             "Today’s Paper", 
             "Travel", 
             "U.S.", 
             "World", 
             "Your Money"]
# Initialize empty list to hold words
facets = []

# Loop through each type
for type in type_list:
    # Starting URL for NYT Most Viewed API Call
    url = f"http://api.nytimes.com/svc/mostpopular/v2/mostviewed/{type}/30.json?offset=40"
    #http://api.nytimes.com/svc/mostpopular/v2/mostviewed/arts/30.json?offset=40
    query_url = f"{url}api-key={api_key}"
    response = requests.get(query_url).json()
   # pprint(response)

# %%
# Loop through the list of articles, remove common punctuation, and perform a split
    for result in range(len(response["results"])):
        text = response["results"][result]['des_facet']
        for facets in text:
            facets.append(facets.lower())
            print(Facets)
# Out:
#   File "<ipython-input-7-1d2b1e6a9cbc>", line 2
#     for result in range(len(response["results"])):
#     ^
# IndentationError: unexpected indent

# %%
# Create DataFrame with the top 5 (by value count) queries# Create 
facet_df = pd.DataFrame(facets).rename(columns={0:"Number of Appearances"})
top_queries = pd.DataFrame(facet_df['Number of Appearances'].value_counts()).head(20)
top_queries_reset = top_queries.reset_index()
top_queries_rnm = top_queries_reset.rename(columns={"index":"Facet"})
top_queries_rn
