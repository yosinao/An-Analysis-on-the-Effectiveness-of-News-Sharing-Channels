# %%
from pytrends.request import TrendReq
from pprint import pprint
from config import api_key
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gmaps
import json
import requests
gkey = "AIzaSyDdb6E3Cn4wbQbYrCBPDkge9XQk4k5siMk"

# %%
df = pd.read_csv("project1.csv")
df
# Out:
#                                    Unnamed: 0  Words
# 0                       ROMAN CATHOLIC CHURCH      5
# 1       UNITED STATES POLITICS AND GOVERNMENT      2
# 2                SUITS AND LITIGATION (CIVIL)      2
# 3                            REPUBLICAN PARTY      2
# 4         ESPIONAGE AND INTELLIGENCE SERVICES      2
# 5         ELECTIONS, HOUSE OF REPRESENTATIVES      2
# 6                              NEW YORK TIMES      2
# 7       UNITED STATES INTERNATIONAL RELATIONS      2
# 8                            DEMOCRATIC PARTY      2
# 9      ISLAMIC STATE IN IRAQ AND SYRIA (ISIS)      2
# 10  UNITED STATES DEFENSE AND MILITARY FORCES      1
# 11                               GRU (RUSSIA)      1
# 12            ENVIRONMENTAL PROTECTION AGENCY      1
# 13                           LEGAL PROFESSION      1
# 14    EUROPEAN SOVEREIGN DEBT CRISIS (2010- )      1
# 15           ANIMAL ABUSE, RIGHTS AND WELFARE      1
# 16                  RUMORS AND MISINFORMATION      1
# 17                 UNITED STATES MARINE CORPS      1
# 18            CRUISE LINES INTERNATIONAL ASSN      1
# 19                          VOTING AND VOTERS      1
# 20             ENDANGERED AND EXTINCT SPECIES      1
# 21                                  WITNESSES      1
# 22           EXECUTIVE PRIVILEGE, DOCTRINE OF      1
# 23                    EMBARGOES AND SANCTIONS      1
# 24                                GUN CONTROL      1
# 25         SCHOOL SHOOTINGS AND ARMED ATTACKS      1
# 26                                   CURRENCY      1
# 27                     LANGUAGE AND LANGUAGES      1
# 28         DEMONSTRATIONS, PROTESTS AND RIOTS      1
# 29                           FOX NEWS CHANNEL      1
# 30                   COURTS AND THE JUDICIARY      1
# 31                     DECISIONS AND VERDICTS      1
# 32              PRESIDENTIAL ELECTION OF 2016      1
# 33                            HOME BOX OFFICE      1
# 34                                ENVIRONMENT      1
# 35                         JUSTICE DEPARTMENT      1
# 36                     CHILDREN AND CHILDHOOD      1
# 37                 WORLD TOURISM ORGANIZATION      1
# 38                       WORLD HERITAGE SITES      1
# 39                SUBMARINES AND SUBMERSIBLES      1
# 40                    STATUTES OF LIMITATIONS      1
# 41                   NATIONAL WEATHER SERVICE      1
# 42                         UNITED STATES NAVY      1
# 43                          ELECTIONS, SENATE      1
# 44              HOMOSEXUALITY AND BISEXUALITY      1
# 45                 IMMIGRATION AND EMIGRATION      1
# 46                    AGRICULTURE AND FARMING      1
# 47                   UNIVERSITY OF NOTTINGHAM      1
# 48                               BIODIVERSITY      1
# 49           PEOPLE'S LIBERATION ARMY (CHINA)      1
# 50               HOMELAND SECURITY DEPARTMENT      1
# 51             PARKLAND, FLA, SHOOTING (2018)      1
# 52                          LAND USE POLICIES      1
# 53                               MICROBIOLOGY      1
# 54                   ELECTRIC LIGHT AND POWER      1
# 55                           SUNRISE MOVEMENT      1

# %%
flat_list = []
for i in range(len(df)):
    if df.iloc[i, 1] > 1:
        flat_list.append(df.iloc[i,0])
        
flat_list
# Out:
# ['ROMAN CATHOLIC CHURCH',
#  'UNITED STATES POLITICS AND GOVERNMENT',
#  'SUITS AND LITIGATION (CIVIL)',
#  'REPUBLICAN PARTY',
#  'ESPIONAGE AND INTELLIGENCE SERVICES',
#  'ELECTIONS, HOUSE OF REPRESENTATIVES',
#  'NEW YORK TIMES',
#  'UNITED STATES INTERNATIONAL RELATIONS',
#  'DEMOCRATIC PARTY',
#  'ISLAMIC STATE IN IRAQ AND SYRIA (ISIS)']

# %%
pytrends.build_payload(kw_list, cat=0, timeframe='2017-12-01 2018-09-06', geo='US',gprop='')
